# %% [markdown]
# # 워드 클라우드

# %%
from wordcloud import WordCloud, STOPWORDS
from PIL import Image

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib as mpl 
import matplotlib.pyplot as plt 
from matplotlib import rc
# %matplotlib inline
# 한글폰트 사용
mpl.rc('font', family='Malgun Gothic')
mpl.rc('axes', unicode_minus=False)

# %% [markdown]
# ### Alice in Wonderland

# %%
text = open('./data/Alice.txt').read()
stopwords = set(STOPWORDS)
stopwords.add('said')

# %%
print(stopwords)
# Out:
# {"when's", 'you', 'against', 'the', 'what', "can't", 'am', 'its', 'like', 'below', 'would', 'themselves', 'there', 'they', 'doing', 'few', 'too', 'to', "i've", 'r', 'your', 'down', "they'll", 'www', 'because', "let's", "it's", 'me', 'ought', 'until', "aren't", 'an', "shouldn't", "i'll", 'do', 'my', 'why', 'both', 'after', 'theirs', 'had', "mustn't", "he's", 'then', "who's", "you'd", "didn't", 'hers', 'again', 'his', 'itself', 'other', 'yourselves', 'some', "don't", 'than', 'above', 'out', 'he', 'cannot', 'else', 'such', 'off', 'been', 'for', 'get', 'ever', 'own', 'could', 'through', 'since', "there's", "won't", 'only', 'who', 'most', "that's", 'we', "what's", "you'll", 'being', 'during', "you're", 'has', 'does', 'each', "couldn't", 'her', 'is', 'are', "i'm", 'them', 'at', "he'll", 'any', 'how', "how's", "i'd", 'him', 'a', "wasn't", 'all', 'have', 'it', "hasn't", "shan't", "she'll", 'when', 'more', 'herself', 'on', 'under', 'those', "we're", 'having', 'did', "where's", 'i', 'with', 'of', "they'd", "hadn't", 'however', 'nor', 'once', "we'd", 'by', 'ourselves', "why's", 'further', 'hence', 'yours', 'about', 'between', 'or', 'into', "wouldn't", 'no', 'be', "she's", 'while', 'these', 'their', 'was', "he'd", 'same', 'which', "you've", 'from', "doesn't", 'therefore', 'before', 'were', 'can', 'not', 'our', "haven't", 'as', 'this', 'in', "here's", "isn't", 'where', 'if', 'just', 'said', 'http', 'over', 'himself', 'com', 'here', "she'd", 'that', 'but', 'whom', "weren't", 'ours', 'very', 'so', 'yourself', 'she', "we've", 'and', 'also', 'up', 'myself', 'should', 'shall', "they're", "we'll", "they've", 'k', 'otherwise'}

# %%
wc = WordCloud(background_color='white', max_words=2000, stopwords=stopwords)
wc = wc.generate(text)

# %%
keys = list(wc.words_.keys())
values = list(wc.words_.values())
for i in range(10):
    print(f'{keys[i]} : {values[i]}')
# Out:
# Alice : 1.0
# little : 0.29508196721311475
# one : 0.27595628415300544
# know : 0.2459016393442623
# went : 0.226775956284153
# thing : 0.2185792349726776
# time : 0.2103825136612022
# Queen : 0.20765027322404372
# see : 0.1830601092896175
# King : 0.17486338797814208

# %%
plt.figure(figsize=(12,6))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# #### 그림에 표시하기

# %%
alice_mask = np.array(Image.open('./data/Alice_mask.png'))

plt.figure(figsize=(8,8))
plt.imshow(alice_mask, cmap=plt.cm.gray, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
wc = WordCloud(background_color='white', max_words=2000,mask=alice_mask, stopwords=stopwords)
wc = wc.generate(text)

# %%
plt.figure(figsize=(12,6))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# ### Star Wars - A New Hope

# %%
text = open('./data/A_new_hope.txt').read()

text = text.replace('HAN','Han')
text = text.replace("LUKE'S", 'Luke')

mask = np.array(Image.open('./data/Stormtrooper_mask.png'))

# %%
stopwords = set(STOPWORDS)
stopwords.add('int')
stopwords.add('ext')

# %%
wc = WordCloud(max_words=1000, mask=mask, stopwords=stopwords, margin=10, random_state=1).generate(text)

default_colors = wc.to_array()

# %%
import random
def grey_color_func(word, font_size, position, orientation, random_state=None, **kwargs):
    return 'hsl(0, 0%%, %d%%)' % random.randint(60, 100)

# %%
plt.figure(figsize=(12,12))
plt.imshow(wc.recolor(color_func=grey_color_func,random_state=3), interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
keys = list(wc.words_.keys())
values = list(wc.words_.values())
for i in range(10):
    print(f'{keys[i]} : {values[i]}')
# Out:
# Luke : 1.0
# Han : 0.45121951219512196
# DEATH STAR : 0.3902439024390244
# THREEPIO : 0.36585365853658536
# Ben : 0.2665505226480836
# Leia : 0.19686411149825783
# ship : 0.19686411149825783
# Artoo : 0.17247386759581881
# one : 0.1672473867595819
# X WING : 0.16550522648083624
